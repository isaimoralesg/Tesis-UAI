# %%
from PIL import Image
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
# !ls
# Out:
# EDA Tesis MIA.ipynb    sample_submission.csv  train.csv
# Preproc Imagenes.ipynb test.csv               trainImages
# catboost_info          testImages

# %%
image_list = []
resized_images = []
widths = []
heights =[]


for filename in glob.glob('trainImages/*.jpg'):
    #print(filename)
    img = Image.open(filename)
    width, height = img.size
    widths.append(width)
    heights.append(height)

# %%
f, ax = plt.subplots(1, 2, sharey=True)
f.suptitle('Distribución de tamaños de imágenes',fontsize=14)
ax[0].hist(heights)
ax[0].set_title('Alto')
ax[1].hist(widths)
ax[1].set_title('Ancho');

# %%
print(f'La mediana para alto es {np.median(heights)} y para ancho es {np.median(widths)}')
# Out:
# La mediana para alto es 200.0 y para ancho es 311.0

# %% [markdown]
# Voy a transformar las imágenes a 200 x 310

# %%
names = [os.path.basename(x) for x in glob.glob('trainImages/*.jpg')]

# %%
names
# Out:
# ['img_4637028.jpg',
#  'img_4535687.jpg',
#  'img_4517432.jpg',
#  'img_4637766.jpg',
#  'img_451186.jpg',
#  'img_4637000.jpg',
#  'img_4635617.jpg',
#  'img_4635824.jpg',
#  'img_4538360.jpg',
#  'img_4517383.jpg',
#  'img_4636487.jpg',
#  'img_4637941.jpg',
#  'img_7764685.jpg',
#  'img_4638496.jpg',
#  'img_4518271.jpg',
#  'img_7766535.jpg',
#  'img_4516248.jpg',
#  'img_4537286.jpg',
#  'img_4515999.jpg',
#  'img_7765014.jpg',
#  'img_4637564.jpg',
#  'img_4538189.jpg',
#  'img_4636849.jpg',
#  'img_4634938.jpg',
#  'img_7765969.jpg',
#  'img_4634910.jpg',
#  'img_4637438.jpg',
#  'img_7769000.jpg',
#  'img_4635549.jpg',
#  'img_4534823.jpg',
#  'img_4635213.jpg',
#  'img_4638723.jpg',
#  'img_4634694.jpg',
#  'img_4637389.jpg',
#  'img_4638904.jpg',
#  'img_4634870.jpg',
#  'img_7768493.jpg',
#  'img_4516880.jpg',
#  'img_4516658.jpg',
#  'img_4635987.jpg',
#  'img_4637160.jpg',
#  'img_7765362.jpg',
#  'img_4514715.jpg',
#  'img_4537127.jpg',
#  'img_4535042.jpg',
# ...

# %%
for filename in glob.glob('trainImages/*.jpg'):
    #print(filename)
    img = Image.open(filename)
    nombre = os.path.basename(filename)
    new_image = img.resize((200, 310))
    new_image.save('trainResizedImages/'+nombre)

# %%
widths, heights = [], []
for filename in glob.glob('trainResizedImages/*.jpg'):
    #print(filename)
    img = Image.open(filename)
    width, height = img.size
    widths.append(width)
    heights.append(height)

# %%
f, ax = plt.subplots(1, 2, sharey=True)
f.suptitle('Distribución de tamaños de imágenes',fontsize=14)
ax[0].hist(heights)
ax[0].set_title('Alto')
ax[1].hist(widths)
ax[1].set_title('Ancho');

# %%
heights
# Out:
# [310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
#  310,
# ...
